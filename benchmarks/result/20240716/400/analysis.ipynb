# %%
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data={}
with open("vllm-1000.0qps-Llama-2-13b-chat-hf-085232-fcfs.json") as f:
    data = json.load(f)

input_length = data['input_lens']
output_length = data['output_lens']
itls = data['itls']

# %%
sns.lineplot(itls[0])
# Out:
# <Axes: >

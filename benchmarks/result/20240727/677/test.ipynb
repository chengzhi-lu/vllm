# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tfittradeoff = pd.read_csv("-1.0qps-Llama-2-13b-chat-hf-105735-tfittradeoff.csv")
sjf = pd.read_csv("-1.0qps-Llama-2-13b-chat-hf-063123-sjf.csv")
fcfs = pd.read_csv("-1.0qps-Llama-2-13b-chat-hf-062526-fcfs.csv")

# %%
sns.histplot(data=tfittradeoff,x='Running', label='tfittradeoff')
sns.histplot(data=sjf,x='Running',label='sjf')
sns.histplot(data=fcfs,x='Running',label='fcfs')
plt.legend()

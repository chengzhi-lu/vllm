# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
result_level_result = pd.read_csv(
    "request_level/request_result_infer_schedule_policy_test_policy.csv"
)

output_dir = "./fig"

# %%
result_level_latency_result=result_level_result[['request_latency','policy']]

# %%
sns.ecdfplot(
    data=result_level_latency_result, x="request_latency", hue="policy"
)
# Out:
# <Axes: xlabel='request_latency', ylabel='Proportion'>
